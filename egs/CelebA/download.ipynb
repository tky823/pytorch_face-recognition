# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z"
# Out:
# img_celeba.7z.001  img_celeba.7z.005  img_celeba.7z.009  img_celeba.7z.013
# img_celeba.7z.002  img_celeba.7z.006  img_celeba.7z.010  img_celeba.7z.014
# img_celeba.7z.003  img_celeba.7z.007  img_celeba.7z.011
# img_celeba.7z.004  img_celeba.7z.008  img_celeba.7z.012

# %%
# !cp -rv "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z" "/content/"
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z' -> '/content/img_celeba_7z'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.001' -> '/content/img_celeba_7z/img_celeba.7z.001'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.002' -> '/content/img_celeba_7z/img_celeba.7z.002'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.003' -> '/content/img_celeba_7z/img_celeba.7z.003'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.004' -> '/content/img_celeba_7z/img_celeba.7z.004'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.005' -> '/content/img_celeba_7z/img_celeba.7z.005'
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/img_celeba.7z.006' -> '/content/img_celeba_7z/img_celeba.7z.006'
# ...

# %%
# %cd "/content/img_celeba_7z"
# Out:
# /content/img_celeba_7z

# %%
!7z x "/content/img_celeba_7z/img_celeba.7z.001"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !ls "/content/img_celeba_7z"
# Out:
# img_celeba	   img_celeba.7z.004  img_celeba.7z.008  img_celeba.7z.012
# img_celeba.7z.001  img_celeba.7z.005  img_celeba.7z.009  img_celeba.7z.013
# img_celeba.7z.002  img_celeba.7z.006  img_celeba.7z.010  img_celeba.7z.014
# img_celeba.7z.003  img_celeba.7z.007  img_celeba.7z.011

# %%
# !cp -rv "/content/img_celeba_7z/img_celeba/" "/content/drive/My Drive/Colab Notebooks/db/CelebA/"
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# '/content/img_celeba_7z/img_celeba/197601.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197601.jpg'
# '/content/img_celeba_7z/img_celeba/197602.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197602.jpg'
# '/content/img_celeba_7z/img_celeba/197603.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197603.jpg'
# '/content/img_celeba_7z/img_celeba/197604.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197604.jpg'
# '/content/img_celeba_7z/img_celeba/197605.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197605.jpg'
# '/content/img_celeba_7z/img_celeba/197606.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197606.jpg'
# '/content/img_celeba_7z/img_celeba/197607.jpg' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/197607.jpg'
# ...

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/000001.jpg"
# Out:
# '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba/000001.jpg'

# %%
# %cd "/content/img_celeba_7z"
# Out:
# /content/img_celeba_7z

# %%
# !zip "train-10000" ./img_celeba/00????.jpg ./img_celeba/010000.jpg
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   adding: img_celeba/005002.jpg (deflated 1%)
#   adding: img_celeba/005003.jpg (deflated 1%)
#   adding: img_celeba/005004.jpg (deflated 2%)
#   adding: img_celeba/005005.jpg (deflated 1%)
#   adding: img_celeba/005006.jpg (deflated 1%)
#   adding: img_celeba/005007.jpg (deflated 1%)
#   adding: img_celeba/005008.jpg (deflated 1%)
#   adding: img_celeba/005009.jpg (deflated 1%)
#   adding: img_celeba/005010.jpg (deflated 1%)
#   adding: img_celeba/005011.jpg (deflated 2%)
#   adding: img_celeba/005012.jpg (deflated 2%)
#   adding: img_celeba/005013.jpg (deflated 1%)
#   adding: img_celeba/005014.jpg (deflated 1%)
#   adding: img_celeba/005015.jpg (deflated 2%)
#   adding: img_celeba/005016.jpg (deflated 1%)
#   adding: img_celeba/005017.jpg (deflated 2%)
#   adding: img_celeba/005018.jpg (deflated 2%)
#   adding: img_celeba/005019.jpg (deflated 1%)
#   adding: img_celeba/005020.jpg (deflated 1%)
#   adding: img_celeba/005021.jpg (deflated 1%)
# ...

# %%
# !zip "valid-1000" ./img_celeba/010???.jpg ./img_celeba/011000.jpg -x ./img_celeba/010000.jpg
# Out:
#   adding: img_celeba/010001.jpg (deflated 2%)
#   adding: img_celeba/010002.jpg (deflated 1%)
#   adding: img_celeba/010003.jpg (deflated 1%)
#   adding: img_celeba/010004.jpg (deflated 1%)
#   adding: img_celeba/010005.jpg (deflated 1%)
#   adding: img_celeba/010006.jpg (deflated 5%)
#   adding: img_celeba/010007.jpg (deflated 1%)
#   adding: img_celeba/010008.jpg (deflated 2%)
#   adding: img_celeba/010009.jpg (deflated 1%)
#   adding: img_celeba/010010.jpg (deflated 4%)
#   adding: img_celeba/010011.jpg (deflated 1%)
#   adding: img_celeba/010012.jpg (deflated 1%)
#   adding: img_celeba/010013.jpg (deflated 2%)
#   adding: img_celeba/010014.jpg (deflated 1%)
#   adding: img_celeba/010015.jpg (deflated 2%)
#   adding: img_celeba/010016.jpg (deflated 1%)
#   adding: img_celeba/010017.jpg (deflated 2%)
#   adding: img_celeba/010018.jpg (deflated 5%)
#   adding: img_celeba/010019.jpg (deflated 2%)
#   adding: img_celeba/010020.jpg (deflated 1%)
# ...

# %%
# !zip "test-5000" ./img_celeba/020*.jpg ./img_celeba/021*.jpg ./img_celeba/022*.jpg ./img_celeba/023*.jpg ./img_celeba/024*.jpg ./img_celeba/025000.jpg -x ./img_celeba/020000.jpg
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   adding: img_celeba/020002.jpg (deflated 1%)
#   adding: img_celeba/020003.jpg (deflated 1%)
#   adding: img_celeba/020004.jpg (deflated 0%)
#   adding: img_celeba/020005.jpg (deflated 2%)
#   adding: img_celeba/020006.jpg (deflated 1%)
#   adding: img_celeba/020007.jpg (deflated 1%)
#   adding: img_celeba/020008.jpg (deflated 2%)
#   adding: img_celeba/020009.jpg (deflated 1%)
#   adding: img_celeba/020010.jpg (deflated 1%)
#   adding: img_celeba/020011.jpg (deflated 1%)
#   adding: img_celeba/020012.jpg (deflated 1%)
#   adding: img_celeba/020013.jpg (deflated 2%)
#   adding: img_celeba/020014.jpg (deflated 1%)
#   adding: img_celeba/020015.jpg (deflated 1%)
#   adding: img_celeba/020016.jpg (deflated 1%)
#   adding: img_celeba/020017.jpg (deflated 1%)
#   adding: img_celeba/020018.jpg (deflated 1%)
#   adding: img_celeba/020019.jpg (deflated 1%)
#   adding: img_celeba/020020.jpg (deflated 3%)
#   adding: img_celeba/020021.jpg (deflated 1%)
# ...

# %%
# !cp -rv "/content/img_celeba_7z/train-10000.zip" "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/"
# Out:
# '/content/img_celeba_7z/train-10000.zip' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/train-10000.zip'

# %%
# !cp -rv "/content/img_celeba_7z/valid-1000.zip" "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/"
# Out:
# '/content/img_celeba_7z/valid-1000.zip' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/valid-1000.zip'

# %%
# !cp -rv "/content/img_celeba_7z/test-5000.zip" "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/"
# Out:
# '/content/img_celeba_7z/test-5000.zip' -> '/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/test-5000.zip'

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/db/CelebA/img_celeba_7z/"
# Out:
# img_celeba.7z.001  img_celeba.7z.006  img_celeba.7z.011  train-10000.zip
# img_celeba.7z.002  img_celeba.7z.007  img_celeba.7z.012  valid-1000.zip
# img_celeba.7z.003  img_celeba.7z.008  img_celeba.7z.013
# img_celeba.7z.004  img_celeba.7z.009  img_celeba.7z.014
# img_celeba.7z.005  img_celeba.7z.010  test-5000.zip
