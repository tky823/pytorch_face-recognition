# %%
# !nvidia-smi
# Out:
# Sat Aug  1 08:15:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r "/content/drive/My Drive/Colab Notebooks/work/pytorch-face_recognition/" "/content/"

# %%
# %cd "/content/pytorch-face_recognition/dataset/CelebA"
# Out:
# /content/pytorch-face_recognition/dataset/CelebA

# %%
# !unzip "/content/pytorch-face_recognition/dataset/CelebA/img_celeba_7z/test-5000.zip"

# %%
# %cd "/content/pytorch-face_recognition/egs/CelebA/u_net"
# Out:
# /content/pytorch-face_recognition/egs/CelebA/u_net

# %%
# !chmod +x "./local/eval_center_net.py"

# %%
model = "UNet_H256_W256_G1_R4_dilated1_separable1_max-pool_bce_[1.0,1.0,1.0]_adam0.001_b32_e50/model/best.pth"

# %%
# !. ./eval.sh "/content/drive/My Drive/Colab Notebooks/work/pytorch-face_recognition/egs/CelebA/u_net/exp" "/content/pytorch-face_recognition/egs/CelebA/u_net/exp/$model"
# Out:
# Namespace(G=1, H=256, K=2, K_backbone=3, K_down=3, R=4, S_backbone=1, S_down=2, W=256, channels='[64,128,256,512]', dilated=1, eval_dir='/content/drive/My Drive/Colab Notebooks/work/pytorch-face_recognition/egs/CelebA/u_net/exp/UNet_H256_W256_G1_R4_dilated1_separable0_max-pool_bce_[1.0,1.0,1.0]_adam0.001_b32_e50/eval', model_path='/content/pytorch-face_recognition/egs/CelebA/u_net/exp/UNet_H256_W256_G1_R4_dilated1_separable0_max-pool_bce_[1.0,1.0,1.0]_adam0.001_b32_e50/model/best.pth', n_candidate=10, nonlinear_backbone='relu', pool_backbone='max', pool_down='max', separable=0, test_image_root='../../../dataset/CelebA/img_celeba', test_path='../../../dataset/CelebA/annotations/test.txt')
# Test dataset includes 5000 images.
# CenterNet(
#   (downsample_net): DownsampleNetBase(
#     (net): Sequential(
#       (0): DownsampleBlock(
#         (conv2d): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
# ...
